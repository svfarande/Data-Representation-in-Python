# %% [markdown]
# # Scatterplots

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x = np.array(np.arange(1,9))
y = x
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
colours = ['green']*(len(x)-1)
colours.append('red')
plt.scatter(x,y,c=colours,s=100)
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
zip_generator = zip(list(range(1,6)), list(range(6,11)))
zip_generator

# %%
list(zip_generator)
# Out:
# [(1, 6), (2, 7), (3, 8), (4, 9), (5, 10)]

# %%
zip_generator = zip(list(range(1,6)), list(range(6,11)))
x, y = zip(*zip_generator)
x
# Out:
# (1, 2, 3, 4, 5)

# %%
y
# Out:
# (6, 7, 8, 9, 10)

# %%
plt.scatter(x[:2],y[:2], s=50, c='red', label='Short students')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
plt.scatter(x[2:],y[2:], s=50, c='green', label='Tall students')

# %%
plt.xlabel('The number of times the child kicked a ball')
plt.ylabel('The grade of student')
plt.title('Relationship between ball kicking and grades')
# Out:
# Text(0.5, 1.0, 'Relationship between ball kicking and grades')

# %%
plt.legend() # Default top left corner

# %%
plt.legend(loc=4, frameon=False, title='Legend') # 4 is lower right corner

# %%
plt.gca().get_children()
# Out:
# ...
#  Text(0.5, 1.0, 'Relationship between ball kicking and grades'),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %%
legend = plt.gca().get_children()[-2]
legend.get_children()[0].get_children()[1].get_children()[0].get_children()

# %%
from matplotlib.artist import Artist

def rec_gc(art, depth=0):
    if isinstance(art, Artist):
        print(" " * depth + str(art))
        for child in art.get_children():
            rec_gc(child, depth+2)

rec_gc(legend)
# Out:
# Legend
# ...
#       Text(0, 0, 'Legend')
# ...
#             Text(0, 0, 'Short students')
# ...
#             Text(0, 0, 'Tall students')
#   FancyBboxPatch((523.842, 75.1643), width=192.271, height=85.5104)
