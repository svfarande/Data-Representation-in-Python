# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
linear_data = np.arange(1,9)
linear_data
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
plt.figure()
xvals = range(1,len(linear_data)+1)
plt.bar(xvals,linear_data,width=0.3,color='blue')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
# <BarContainer object of 8 artists>

# %%
new_vals = []
for item in xvals:
    new_vals.append(item+0.3)
new_vals
# Out:
# [1.3, 2.3, 3.3, 4.3, 5.3, 6.3, 7.3, 8.3]

# %%
quadratic_data = linear_data ** 2
quadratic_data
# Out:
# array([ 1,  4,  9, 16, 25, 36, 49, 64], dtype=int32)

# %%
plt.bar(new_vals, quadratic_data, width=0.3, color='red')
# Out:
# <BarContainer object of 8 artists>

# %%
linear_err = np.array(np.random.randint(1,15,len(linear_data)))
linear_err
# Out:
# array([10,  6,  9, 12, 14,  4, 11,  4])

# %%
plt.bar(xvals, linear_data, width=0.3, yerr=linear_err, color='blue')
plt.legend(['Linear', 'Quadratic'])
plt.title('Linear $x$ vs Quadratic $x^2$')
# Out:
# Text(0.5, 1.0, 'Linear $x$ vs Quadratic $x^2$')

# %%
plt.figure()
plt.bar(xvals, linear_data, width=0.3, color='b')
plt.bar(xvals, quadratic_data, width=0.3, color='g', bottom=linear_data)
plt.legend(['Linear', 'Quadratic'])
plt.title('Linear $x$ vs Quadratic $x^2$')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
# Text(0.5, 1.0, 'Linear $x$ vs Quadratic $x^2$')

# %%
plt.figure()
plt.barh(xvals, linear_data, height=0.3, color='b')
plt.barh(xvals, quadratic_data, height=0.3, color='g',left=linear_data)
plt.legend(['Linear', 'Quadratic'])
plt.title('Linear $x$ vs Quadratic $x^2$')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
# Text(0.5, 1.0, 'Linear $x$ vs Quadratic $x^2$')

# %% [markdown]
# ### Plot number of NULL value in dataframe

# %%
df = pd.DataFrame(np.reshape(np.random.randint(10,99,8*8),(8,8)))
df
# Out:
#     0   1   2   3   4   5   6   7
# 0  31  89  76  52  50  49  26  28
# 1  55  91  89  88  76  38  52  20
# 2  30  42  90  47  62  71  28  83
# 3  32  49  87  16  88  41  85  59
# 4  62  71  42  90  85  55  75  26
# 5  42  91  48  41  44  89  20  29
# 6  14  47  24  73  54  16  87  29
# 7  88  73  25  93  85  71  83  41

# %%
df.iloc[5,2:6] = np.nan
df.iloc[0,3:8] = np.nan
df.iloc[3,5:6] = np.nan
df.iloc[2,7:8] = np.nan
df.iloc[4,1:8] = np.nan
df.iloc[7,4:7] = np.nan
df.columns = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
df
# Out:
#    one   two  three  four  five   six  seven  eight
# 0   31  89.0   76.0   NaN   NaN   NaN    NaN    NaN
# 1   55  91.0   89.0  88.0  76.0  38.0   52.0   20.0
# 2   30  42.0   90.0  47.0  62.0  71.0   28.0    NaN
# 3   32  49.0   87.0  16.0  88.0   NaN   85.0   59.0
# 4   62   NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 5   42  91.0    NaN   NaN   NaN   NaN   20.0   29.0
# 6   14  47.0   24.0  73.0  54.0  16.0   87.0   29.0
# 7   88  73.0   25.0  93.0   NaN   NaN    NaN   41.0

# %%
df.isna().sum().plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
# <AxesSubplot:>
