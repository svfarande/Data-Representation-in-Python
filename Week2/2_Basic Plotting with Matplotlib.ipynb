# %% [markdown]
# # Basic Plotting with Matplotlib

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot(3,2,'.')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img src='test.png'/>
# Out:
# <img src='test.png'/>

# %%
plt.figure()
plt.plot(2,3,'o')
ax = plt.gca()
ax.axis([0,5,0,8])
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
# (0.0, 5.0, 0.0, 8.0)

# %%
plt.figure()
plt.plot(1,2,'o')
plt.plot(2,3,'o')
plt.plot(3,4,'o')
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
ax = plt.gca()
ax.get_children()
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
# [<matplotlib.spines.Spine at 0x1dcaed30d30>,
#  <matplotlib.spines.Spine at 0x1dcaed30a90>,
#  <matplotlib.spines.Spine at 0x1dcaeb775b0>,
#  <matplotlib.spines.Spine at 0x1dcaeb6e430>,
#  <matplotlib.axis.XAxis at 0x1dcaed30c40>,
#  <matplotlib.axis.YAxis at 0x1dcaf5c1940>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0x1dcaed12550>]
