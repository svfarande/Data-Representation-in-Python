# %% [markdown]
# # Box Plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal' : normal_sample,
                   'random' : random_sample,
                   'gamma' : gamma_sample})
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.012825      0.497402      2.009484
# std        1.007298      0.289419      1.413143
# min       -3.331977      0.000038      0.002851
# 25%       -0.687267      0.246978      0.976817
# 50%       -0.018833      0.491710      1.689651
# 75%        0.663063      0.748808      2.717755
# max        4.110558      0.999996     13.812444

# %%
temp = pd.DataFrame(np.arange(11))
temp.describe()
# Out:
#                0
# count  11.000000
# mean    5.000000
# std     3.316625
# min     0.000000
# 25%     2.500000
# 50%     5.000000
# 75%     7.500000
# max    10.000000

# %%
plt.figure()
_ = plt.boxplot(df['normal'], whis=[0, 100])
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
plt.figure()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis=[0,100])
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
plt.figure()
_  = plt.hist(df['gamma'], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis=[0,100])
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
ax2.yaxis.tick_right()
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">

# %%
# when we don't use whiskers
plt.figure()
_ = plt.boxplot([df['normal'],df['random'],df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="639.4710340596957">
